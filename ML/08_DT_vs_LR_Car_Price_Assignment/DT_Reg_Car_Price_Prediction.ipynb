# %%
#Predicting car price from automobile data using decision tree regressor

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

from sklearn.preprocessing import LabelEncoder, StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
data = pd.read_csv("Automobile_data.csv")
data.replace("?", np.nan, inplace =True)

# %%
data['price'] = pd.to_numeric(data['price'], errors ='raise')
categorical_columns = data.select_dtypes(include = ['object']).columns.tolist()
numerical_columns = data.select_dtypes(include = ['int64', 'float64']).columns.tolist()

# %%
for col in categorical_columns:
    le = LabelEncoder()
    data[col] = le.fit_transform(data[col])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    int64
#  2   make               205 non-null    int64
#  3   fuel-type          205 non-null    int64
#  4   aspiration         205 non-null    int64
#  5   num-of-doors       205 non-null    int64
#  6   body-style         205 non-null    int64
#  7   drive-wheels       205 non-null    int64
#  8   engine-location    205 non-null    int64
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    int64
#  15  num-of-cylinders   205 non-null    int64
#  16  engine-size        205 non-null    int64
#  17  fuel-system        205 non-null    int64
#  18  bore               205 non-null    int64
#  19  stroke             205 non-null    int64
#  20  compression-ratio  205 non-null    float64
#  21  horsepower         205 non-null    int64
#  22  peak-rpm           205 non-null    int64
#  23  city-mpg           205 non-null    int64
#  24  highway-mpg        205 non-null    int64
#  25  price              201 non-null    float64
# dtypes: float64(6), int64(20)
# memory usage: 41.8 KB

# %%
#impute missing values using desicion tree regressor
for col in data.columns:
    if data[col].isnull().sum()>0:
        known_data = data[data[col].notnull()]
        unknown_data = data[data[col].isnull()]

        X_train_imp = known_data.drop(col, axis=1)# Train features to predict missing values
        y_train_imp = known_data[col]#Train target variable to predict missing values
        X_unknown_imp = unknown_data.drop(col, axis = 1)# Actual features to predict missing values

        
        dt_reg_imp = DecisionTreeRegressor()
        dt_reg_imp.fit(X_train_imp, y_train_imp) #train the model to predict missing values
        data.loc[data[col].isnull(), col ] = dt_reg_imp.predict(X_unknown_imp) # predict missing values and fill them in the dataframe

# %%
# Explore the data
data.describe()
# Out:
#         symboling  normalized-losses        make   fuel-type  aspiration  \
# count  205.000000         205.000000  205.000000  205.000000  205.000000
# mean     0.834146          29.853659   12.195122    0.902439    0.180488
# std      1.245307          17.197470    6.274831    0.297446    0.385535
# min     -2.000000           0.000000    0.000000    0.000000    0.000000
# 25%      0.000000          15.000000    8.000000    1.000000    0.000000
# 50%      1.000000          28.000000   12.000000    1.000000    0.000000
# 75%      2.000000          48.000000   19.000000    1.000000    0.000000
# max      3.000000          51.000000   21.000000    1.000000    1.000000
#
#        num-of-doors  body-style  drive-wheels  engine-location  wheel-base  \
# count    205.000000  205.000000    205.000000       205.000000  205.000000
# mean       0.453659    2.614634      1.326829         0.014634   98.756585
# std        0.518339    0.859081      0.556171         0.120377    6.021776
# min        0.000000    0.000000      0.000000         0.000000   86.600000
# 25%        0.000000    2.000000      1.000000         0.000000   94.500000
# 50%        0.000000    3.000000      1.000000         0.000000   97.000000
# 75%        1.000000    3.000000      2.000000         0.000000  102.400000
# max        2.000000    4.000000      2.000000         1.000000  120.900000
#
#        ...  engine-size  fuel-system        bore      stroke  \
# count  ...   205.000000   205.000000  205.000000  205.000000
# mean   ...   126.907317     3.253659   18.336585   19.551220
# std    ...    41.642693     2.013204   10.368640    8.898863
# min    ...    61.000000     0.000000    0.000000    0.000000
# 25%    ...    97.000000     1.000000   11.000000   13.000000
# 50%    ...   120.000000     5.000000   16.000000   21.000000
# 75%    ...   141.000000     5.000000   28.000000   25.000000
# max    ...   326.000000     7.000000   38.000000   36.000000
#
#        compression-ratio  horsepower    peak-rpm    city-mpg  highway-mpg  \
# count         205.000000  205.000000  205.000000  205.000000   205.000000
# mean           10.142537   31.726829   11.604878   25.219512    30.751220
# std             3.972040   18.572949    5.318758    6.542142     6.886443
# min             7.000000    0.000000    0.000000   13.000000    16.000000
# 25%             8.600000   12.000000    8.000000   19.000000    25.000000
# 50%             9.000000   40.000000   12.000000   24.000000    30.000000
# 75%             9.400000   47.000000   16.000000   30.000000    34.000000
# max            23.000000   59.000000   23.000000   49.000000    54.000000
#
#               price
# count    205.000000
# mean   13271.234146
# std     8073.538574
# min     5118.000000
# 25%     7775.000000
# 50%    10295.000000
# 75%    16500.000000
# max    45400.000000
#
# [8 rows x 26 columns]

# %%
data.corr()['price'].sort_values(ascending=False)
# Out:
# price                1.000000
# engine-size          0.873795
# curb-weight          0.834993
# width                0.763932
# length               0.680607
# drive-wheels         0.579795
# wheel-base           0.573706
# bore                 0.537574
# fuel-system          0.527031
# normalized-losses    0.384594
# engine-location      0.321647
# aspiration           0.174239
# height               0.116523
# compression-ratio    0.068239
# stroke               0.045113
# engine-type          0.042356
# num-of-cylinders    -0.034562
# num-of-doors        -0.039223
# symboling           -0.077289
# body-style          -0.086313
# peak-rpm            -0.089239
# fuel-type           -0.104795
# make                -0.146231
# horsepower          -0.337390
# city-mpg            -0.687794
# highway-mpg         -0.696224
# Name: price, dtype: float64

# %%
data.drop(columns=['normalized-losses','symboling','peak-rpm','city-mpg','highway-mpg'], inplace=True)

# %%
y = data['price']
X = data.drop('price', axis=1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)
dt_reg = DecisionTreeRegressor(random_state=42)
dt_reg.fit(X_train, y_train)
y_pred = dt_reg.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
print(f"Mean Absolute Error: {mae}")
print(f"Mean Squared Error: {mse}") 
print(f"Root Mean Squared Error: {rmse}") 
print(f"R^2 Score: {r2}")
# Out:
# Mean Absolute Error: 1832.6463414634147
# Mean Squared Error: 8565996.451219512
# Root Mean Squared Error: 2926.772360676435
# R^2 Score: 0.855050340482389
